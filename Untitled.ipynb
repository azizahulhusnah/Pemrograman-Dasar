# %% [markdown]
# <a href="https://colab.research.google.com/github/azizahulhusnah/Pemrograman-Dasar/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# deklarasi variabel list
numbers = [23, 43, 15, 34]

print(numbers)

# cara mengakses elemen dalam variabel list
print(numbers[0])  # 23
print(numbers[1])  # 43
print(numbers[2])  # 15
print(numbers[3])  # 34

# cara mengubah nilai elemen dalam variabel list
numbers[2] = 51
print(numbers [2])  # [23, 43, 51, 34]

# print salah satu elemen
print(numbers[1])  # 43

# deklarasi variabel list
numbers = [1, 2, 3]

# menambahkan elemen di indeks ke-4
numbers.insert(3, 5)  # indeks dimulai dari 0, jadi 3 = posisi ke-4
print(numbers)  # [1, 2, 3, 5]

# mengubah elemen di indeks ke-4
numbers[3] = 4
print(numbers)  # [1, 2, 3, 4]

# menghapus elemen di indeks ke-2
numbers.pop(2)
print(numbers)  # [1, 2, 4]





# deklarasi variabel list numbers
numbers = [1, 2, 3]

# menambahkan elemen di indeks ke-4
numbers.insert(4, 5)   # [1, 2, 3, 5]
print(numbers)

# mengubah elemen di indeks ke-4
numbers[3] = 4         # [1, 2, 3, 4]
print(numbers)

# menghapus elemen di indeks ke-2
numbers.pop(2)         # [1, 2, 4]
print(numbers)


# --------------------------------------------------

# deklarasi variabel list campuran
myList = [1, "Rumah", 4.5, True, ["Kamar mandi", "Kamar tidur"]]

# cara mengakses elemen dalam variabel list
print(myList[0])   # 1
print(myList[1])   # "Rumah"
print(myList[3])   # True
print(myList[4])   # ["Kamar mandi", "Kamar tidur"]

# cara mengakses elemen dalam sublist
print(myList[4][0])   # "Kamar mandi"
print(myList[4][1])   # "Kamar tidur"



# deklarasi variabel tuple
numbers = (23, 43, 15, 34)

# cara mengakses elemen dalam variabel tuple
print(numbers[0])   # 23
print(numbers[1])   # 43
print(numbers[2])   # 15



# deklarasi variabel set a dan b
a = {1, 2, 3}
b = {2, 3, 4}

# operasi gabungan
print(a.union(b))            # {1, 2, 3, 4}

# operasi irisan
print(a.intersection(b))     # {2, 3}

# operasi perbedaan simetris
print(a.symmetric_difference(b))   # {1, 4}



# deklarasi variabel dictionary
propertyDetail = {
    "numFloors": 1,
    "propertyType": "Rumah",
    "hasTerrace": True,
    "hasGarage": False
}

# cara mengakses elemen dalam variabel dictionary
print(propertyDetail["numFloors"])     # 1
print(propertyDetail["propertyType"])  # Rumah
print(propertyDetail["hasTerrace"])    # True
print(propertyDetail["hasGarage"])     # False

# cara mengubah nilai elemen dalam variabel dictionary
propertyDetail["hasTerrace"] = False

print(propertyDetail["hasTerrace"])    # False

# contoh akses lain
print(propertyDetail["propertyType"])  # Rumah

x = "Belajar"

y = "Python"

result = x > y

print(result)

x = 10

y = 999

result = x > y

print(result)

x = "Poli"

y = "Batam"

result = x >= y
print(result)
# Out:
# [23, 43, 15, 34]
# 23
# 43
# 15
# 34
# 51
# 43
# [1, 2, 3, 5]
# [1, 2, 3, 4]
# [1, 2, 4]
# [1, 2, 3, 5]
# [1, 2, 3, 4]
# [1, 2, 4]
# 1
# Rumah
# True
# ['Kamar mandi', 'Kamar tidur']
# Kamar mandi
# Kamar tidur
# 23
# 43
# 15
# {1, 2, 3, 4}
# {2, 3}
# {1, 4}
# 1
# Rumah
# True
# False
# False
# Rumah
# False
# False
# True
